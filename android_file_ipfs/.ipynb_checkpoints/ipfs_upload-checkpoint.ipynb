# %%
import ipfshttpclient
import os
from pathlib import Path
from web3 import Web3
import json

path=Path()
client=ipfshttpclient.connect('/ip4/127.0.0.1/tcp/5001/http')
print(client)
url = "http://localhost:7545"
web3 = Web3(Web3.HTTPProvider(url))
print(web3.isConnected())
web3.eth.defaultAccount = web3.eth.accounts[0]
address=web3.toChecksumAddress('0x2d2dcbb186b7feee17e44d9403462a7bbfcc76b8')


abi = json.loads('[{"constant":true,"inputs":[],"name":"get_data","outputs":[{"name":"","type":"string"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[{"name":"_name","type":"string"}],"name":"set_data","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[],"name":"data","outputs":[{"name":"","type":"string"}],"payable":false,"stateMutability":"view","type":"function"}]')
contract = web3.eth.contract(address=address, abi=abi)
# Out:
# <ipfshttpclient.client.Client object at 0x0000026C3A710688>
# True

# %%
while True:
    f=open('status.txt','r')
    status=f.read()
    f.close()
    if status=='upload':
        f=open('fname.txt','r')
        fname=f.read()
        f.close()
        print("fname",fname)
        res=client.add(fname)
        print(res)
        print(res['Name'])
        print(res['Hash'])
        print(res['Size'])
        os.remove(fname)
        hash_fname=fname+"_hash.txt"
        print("read",hash_fname)
        f=open(hash_fname,'r')
        fhash=f.read()
        f.close()
        print("fhash",fhash)
        blk_info=fname+"##@@"+fhash+"##@@"+res['Hash']+'##@@'+res['Size']
        print(blk_info)

        chain_data=contract.functions.get_data().call()
        print("old data",chain_data)
        new_data=chain_data+"%%@@"+blk_info
        resp = contract.functions.set_data(new_data).transact()
        web3.eth.waitForTransactionReceipt(resp)
        print('resp=',resp)
        f=open('status.txt','w')
        f.write('')
        f.close()
        os.remove(hash_fname)
    elif status=='get_file_names':
        f=open('user.txt','r')
        email=f.read()
        f.close()
        chain_data=contract.functions.get_data().call()
        print("old data",chain_data)
        l=chain_data.split('%%@@')
        f=open('list.txt','w')
        f.write('')
        f.close()
        f=open("list.txt",'a')
        for x in l:
            l1=x.split('##@@')
            if str(l1[0]).startswith(email):
                arr=l1[0].split('_')
                fname=arr[1]
                fhash=l1[1]
                ipfs_hash=l1[2]
                fsize=l1[3]
                print(fname,fhash,ipfs_hash,fsize)
                f.write(fname+"##"+fhash+"##"+ipfs_hash+"##"+fsize+"\n")
        f.close()
        f=open('status.txt','w')
        f.write('')
        f.close()
    elif status=='get_file':
        f=open('fname.txt','r')
        fname=f.read()
        f.close()
        f=open('list.txt','r')
        fdet=f.read()
        f.close()
        l=fdet.split('\n')
        print("l=",l)
        for x in l:
            print(x,type(x))
            l1=x.split('##')
            if l1[0]==fname:
                fhash=l1[1]
                ipfs_hash=l1[2]
                getfile=client.cat(ipfs_hash)
                f = open(fname, "wb")
                f.write(getfile)
                f.close()
        f=open(fname+'_hash.txt','w')
        f.write(fhash)
        f.close()
        
        f=open('status.txt','w')
        f.write('')
        f.close()
# Out:
# l= ['ff.pdf##fd3937b203320c3214378b5959db6be2e606ffaa6eb9ee102241c41fc3171000##QmTC1rXhnbet9894m5QFsWhj5aQ1NNpL5d4CwfDVaHkjy9##7315169', 'yy.pdf##fa4380fa88b82afc21ca904a479d2608593e0a4089dd10d35d236915a8d7ddf7##QmSd7YUxnrvyNf79P3fbk1B2ib1BZ8P1Lm95194utDkABo##4120934', 'op.pdf##f7920f352ae4eaa5ad96154a63d78d68902919a0ea9f92f5795d01b8dc755b1e##QmZPpeDz9yQCZnp7bWxAnmZxtJnATaZQEaXdCmECsJexN9##3072814', '']
# ff.pdf##fd3937b203320c3214378b5959db6be2e606ffaa6eb9ee102241c41fc3171000##QmTC1rXhnbet9894m5QFsWhj5aQ1NNpL5d4CwfDVaHkjy9##7315169 <class 'str'>
# yy.pdf##fa4380fa88b82afc21ca904a479d2608593e0a4089dd10d35d236915a8d7ddf7##QmSd7YUxnrvyNf79P3fbk1B2ib1BZ8P1Lm95194utDkABo##4120934 <class 'str'>
# op.pdf##f7920f352ae4eaa5ad96154a63d78d68902919a0ea9f92f5795d01b8dc755b1e##QmZPpeDz9yQCZnp7bWxAnmZxtJnATaZQEaXdCmECsJexN9##3072814 <class 'str'>
#  <class 'str'>
# fname sumit@gmail.com_po.pdf
# <ipfshttpclient.client.base.ResponseBase: {'Name': 'sumit@gmail.com_po.pdf', 'Hash': 'QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr', 'Size': '4322677'}>
# sumit@gmail.com_po.pdf
# QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr
# 4322677
# read sumit@gmail.com_po.pdf_hash.txt
# fhash b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709
# sumit@gmail.com_po.pdf##@@b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##@@QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##@@4322677
# old data
# resp= b'\xa2_\xf3\x92\xcc\x98\xa0\xdd8\xf3tce\x0bJ\x82tb\xde\xf3\x87O\x1cU\x88z#\xc0\xb1n\x0c\xff'
# fname sumit@gmail.com_rrrr.pdf
# <ipfshttpclient.client.base.ResponseBase: {'Name': 'sumit@gmail.com_rrrr.pdf', 'Hash': 'QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT', 'Size': '8311919'}>
# sumit@gmail.com_rrrr.pdf
# QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT
# 8311919
# read sumit@gmail.com_rrrr.pdf_hash.txt
# fhash 989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b
# sumit@gmail.com_rrrr.pdf##@@989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##@@QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##@@8311919
# old data %%@@sumit@gmail.com_po.pdf##@@b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##@@QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##@@4322677
# resp= b'\x82\x9f\xeePN\x1c\xa41\xb8\x8d\xe5Vc\x00\x8fq\x0eX\x07\x81\xeczG\x17\x83\x16\x9bVr<\x07\x8e'
# old data %%@@sumit@gmail.com_po.pdf##@@b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##@@QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##@@4322677%%@@sumit@gmail.com_rrrr.pdf##@@989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##@@QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##@@8311919
# po.pdf b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709 QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr 4322677
# rrrr.pdf 989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT 8311919
# l= ['po.pdf##b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##4322677', 'rrrr.pdf##989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##8311919', '']
# po.pdf##b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##4322677 <class 'str'>
# rrrr.pdf##989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##8311919 <class 'str'>
#  <class 'str'>
# fname ss@g.com_aaaa.pdf
# <ipfshttpclient.client.base.ResponseBase: {'Name': 'ss@g.com_aaaa.pdf', 'Hash': 'QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1', 'Size': '7028543'}>
# ss@g.com_aaaa.pdf
# QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1
# 7028543
# read ss@g.com_aaaa.pdf_hash.txt
# fhash 4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01
# ss@g.com_aaaa.pdf##@@4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##@@QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##@@7028543
# old data %%@@sumit@gmail.com_po.pdf##@@b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##@@QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##@@4322677%%@@sumit@gmail.com_rrrr.pdf##@@989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##@@QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##@@8311919
# resp= b'\x99\xd9u\x99\xfd\xe8\xbf-\xc6E\xc5\x81\x08z\xb8_[j\xf5\xbb\x17=\x14YWQ\\"\x9eS*\x81'
# old data %%@@sumit@gmail.com_po.pdf##@@b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##@@QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##@@4322677%%@@sumit@gmail.com_rrrr.pdf##@@989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##@@QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##@@8311919%%@@ss@g.com_aaaa.pdf##@@4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##@@QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##@@7028543
# aaaa.pdf 4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01 QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1 7028543
# old data %%@@sumit@gmail.com_po.pdf##@@b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##@@QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##@@4322677%%@@sumit@gmail.com_rrrr.pdf##@@989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##@@QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##@@8311919%%@@ss@g.com_aaaa.pdf##@@4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##@@QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##@@7028543
# po.pdf b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709 QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr 4322677
# rrrr.pdf 989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT 8311919
# l= ['po.pdf##b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##4322677', 'rrrr.pdf##989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##8311919', '']
# po.pdf##b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##4322677 <class 'str'>
# rrrr.pdf##989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##8311919 <class 'str'>
#  <class 'str'>
# l= ['po.pdf##b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##4322677', 'rrrr.pdf##989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##8311919', '']
# po.pdf##b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##4322677 <class 'str'>
# rrrr.pdf##989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##8311919 <class 'str'>
#  <class 'str'>
# old data %%@@sumit@gmail.com_po.pdf##@@b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##@@QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##@@4322677%%@@sumit@gmail.com_rrrr.pdf##@@989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##@@QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##@@8311919%%@@ss@g.com_aaaa.pdf##@@4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##@@QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##@@7028543
# aaaa.pdf 4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01 QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1 7028543
# l= ['aaaa.pdf##4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##7028543', '']
# aaaa.pdf##4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##7028543 <class 'str'>
#  <class 'str'>
# old data %%@@sumit@gmail.com_po.pdf##@@b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##@@QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##@@4322677%%@@sumit@gmail.com_rrrr.pdf##@@989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##@@QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##@@8311919%%@@ss@g.com_aaaa.pdf##@@4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##@@QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##@@7028543
# aaaa.pdf 4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01 QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1 7028543
# l= ['aaaa.pdf##4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##7028543', '']
# aaaa.pdf##4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##7028543 <class 'str'>
#  <class 'str'>
# old data %%@@sumit@gmail.com_po.pdf##@@b4e4da0c49cbc2cc9cbd38a34e827c207959326420234405315429357f51b709##@@QmYZoUVDghSHakLie47EcP5oYFpXads2v1ReWuMMhZA6Nr##@@4322677%%@@sumit@gmail.com_rrrr.pdf##@@989293342bceb938a0c1e102d482cdc03d2ae50108c2ca3cd4f006d7a5993d8b##@@QmQqUKkoTYDqxcwcM91dJWTbKhXsw7xCg64Jd4u63HQ4wT##@@8311919%%@@ss@g.com_aaaa.pdf##@@4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##@@QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##@@7028543
# aaaa.pdf 4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01 QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1 7028543
# l= ['aaaa.pdf##4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##7028543', '']
# aaaa.pdf##4b65d6c44b595bfd6561357b1059a233a114ad66557ca2ea9e1d7bde2ab01e01##QmbNvhuz9bv4XcocRHgnde7NVo61JNJrTpL9hNBJe6JuL1##7028543 <class 'str'>
#  <class 'str'>
