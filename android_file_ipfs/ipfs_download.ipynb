# %%
import ipfshttpclient
import os
from pathlib import Path
from web3 import Web3
import json

path=Path()
client=ipfshttpclient.connect('/ip4/127.0.0.1/tcp/5001/http')
print(client)
web3=Web3(Web3.EthereumTesterProvider())
print(web3.isConnected())
web3.eth.defaultAccount = web3.eth.accounts[0]
address=web3.toChecksumAddress('0x0caab5355608dcdf96be7cb3f70ec66f4047fd4d')
abi = json.loads('[{"constant":true,"inputs":[],"name":"get_data","outputs":[{"name":"","type":"string"}],"payable":false,"stateMutability":"view","type":"function"},{"constant":false,"inputs":[{"name":"_name","type":"string"}],"name":"set_data","outputs":[],"payable":false,"stateMutability":"nonpayable","type":"function"},{"constant":true,"inputs":[],"name":"data","outputs":[{"name":"","type":"string"}],"payable":false,"stateMutability":"view","type":"function"}]')
contract = web3.eth.contract(address=address, abi=abi)
# Out:
# <ipfshttpclient.client.Client object at 0x000001B019691EB0>
# True
# C:\ProgramData\Anaconda3\lib\site-packages\eth_tester\backends\__init__.py:30: UserWarning: Ethereum Tester: No backend was explicitely set, and no *full* backends were available.  Falling back to the `MockBackend` which does not support all EVM functionality.  Please refer to the `eth-tester` documentation for information on what backends are available and how to set them.
#   warnings.warn(UserWarning(
# C:\ProgramData\Anaconda3\lib\site-packages\web3\eth.py:258: DeprecationWarning: defaultAccount is deprecated in favor of default_account
#   warnings.warn(

# %%
while True:
    f=open('get.txt','r')
    status=f.read()
    f.close()
    if status=='upload':
        rid=status
        chain_data=contract.functions.get_data().call()
        print("old data",chain_data)
        l=chain_data.split('%%@@')
        for x in l:
            l1=x.split('##@@')
            if str(l1[0]).startswith(rid):
                fname=l1[0]+"_enc.pdf"
                fhash=l1[1]
                ipfs_hash=l1[2]
                fsize=l1[3]
                print(fname,fhash,ipfs_hash,fsize)
                getfile=client.cat(ipfs_hash)
                f = open(fname, "wb")
                f.write(getfile)
                f.close()
                f=open(fname+".txt",'w')
                f.write(fhash)
                f.close()
        f=open('download_status.txt','w')
        f.write('done')
        f.close()
        f=open('get.txt','w')
        f.write('')
        f.close()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-14-53ae60ecd11e>:2: ResourceWarning: unclosed file <_io.TextIOWrapper name='get.txt' mode='r' encoding='cp1252'>
#   f=open('get.txt','r')
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-53ae60ecd11e> in <module>
#       5     if status=='upload':
#       6         rid=status
# ----> 7         chain_data=contract.functions.get_data().call()
#       8         print("old data",chain_data)
#       9         l=chain_data.split('%%@@')
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\contract.py in call(self, transaction, block_identifier)
#     952         block_id = parse_block_identifier(self.web3, block_identifier)
#     953
# --> 954         return call_contract_function(
#     955             self.web3,
#     956             self.address,
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\contract.py in call_contract_function(web3, address, normalizers, function_identifier, transaction, block_id, contract_abi, fn_abi, *args, **kwargs)
#    1497         return_data = web3.eth.call(call_transaction)
#    1498     else:
# -> 1499         return_data = web3.eth.call(call_transaction, block_identifier=block_id)
#    1500
#    1501     if fn_abi is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\module.py in caller(*args, **kwargs)
#      55             return LogFilter(eth_module=module, filter_id=err.filter_id)
#      56         result_formatters, error_formatters = response_formatters
# ---> 57         result = w3.manager.request_blocking(method_str, params, error_formatters)
#      58         return apply_result_formatters(result_formatters, result)
#      59     return caller
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\manager.py in request_blocking(self, method, params, error_formatters)
#     152         Make a synchronous request using the provider
#     153         """
# --> 154         response = self._make_request(method, params)
#     155
#     156         if "error" in response:
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\manager.py in _make_request(self, method, params)
#     131             self.middleware_onion)
#     132         self.logger.debug("Making request. Method: %s", method)
# --> 133         return request_func(method, params)
#     134
#     135     async def _coro_make_request(
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\formatting.py in apply_formatters(method, params, make_request, request_formatters, result_formatters, error_formatters)
#      74         response = make_request(method, formatted_params)
#      75     else:
# ---> 76         response = make_request(method, params)
#      77
#      78     if "result" in response and method in result_formatters:
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\gas_price_strategy.py in middleware(method, params)
#      32                     transaction = assoc(transaction, 'gasPrice', generated_gas_price)
#      33                     return make_request(method, [transaction])
# ---> 34         return make_request(method, params)
#      35     return middleware
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\formatting.py in apply_formatters(method, params, make_request, request_formatters, result_formatters, error_formatters)
#      72         formatter = request_formatters[method]
#      73         formatted_params = formatter(params)
# ---> 74         response = make_request(method, formatted_params)
#      75     else:
#      76         response = make_request(method, params)
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\attrdict.py in middleware(method, params)
#      31     """
#      32     def middleware(method: RPCEndpoint, params: Any) -> RPCResponse:
# ---> 33         response = make_request(method, params)
#      34
#      35         if 'result' in response:
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\formatting.py in apply_formatters(method, params, make_request, request_formatters, result_formatters, error_formatters)
#      72         formatter = request_formatters[method]
#      73         formatted_params = formatter(params)
# ---> 74         response = make_request(method, formatted_params)
#      75     else:
#      76         response = make_request(method, params)
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\normalize_errors.py in middleware(method, params)
#      23 ) -> Callable[[RPCEndpoint, Any], RPCResponse]:
#      24     def middleware(method: RPCEndpoint, params: Any) -> RPCResponse:
# ---> 25         result = make_request(method, params)
#      26
#      27         # As of v1.8, Geth returns errors when you request a
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\formatting.py in apply_formatters(method, params, make_request, request_formatters, result_formatters, error_formatters)
#      72         formatter = request_formatters[method]
#      73         formatted_params = formatter(params)
# ---> 74         response = make_request(method, formatted_params)
#      75     else:
#      76         response = make_request(method, params)
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\formatting.py in apply_formatters(method, params, make_request, request_formatters, result_formatters, error_formatters)
#      72         formatter = request_formatters[method]
#      73         formatted_params = formatter(params)
# ---> 74         response = make_request(method, formatted_params)
#      75     else:
#      76         response = make_request(method, params)
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\providers\eth_tester\middleware.py in middleware(method, params)
#     323         # TODO send call to eth-tester without gas, and remove guess_gas entirely
#     324         if method == 'eth_call':
# --> 325             filled_transaction = pipe(
#     326                 params[0],
#     327                 fill_default_from,
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.pipe()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.c_pipe()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\providers\eth_tester\middleware.py in fill_default(field, guess_func, web3, transaction)
#     310         return transaction
#     311     else:
# --> 312         guess_val = guess_func(web3, transaction)
#     313         return assoc(transaction, field, guess_val)
#     314
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\providers\eth_tester\middleware.py in guess_gas(web3, transaction)
#     299
#     300 def guess_gas(web3: "Web3", transaction: TxParams) -> Wei:
# --> 301     return Wei(web3.eth.estimate_gas(transaction) * 2)
#     302
#     303
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\module.py in caller(*args, **kwargs)
#      55             return LogFilter(eth_module=module, filter_id=err.filter_id)
#      56         result_formatters, error_formatters = response_formatters
# ---> 57         result = w3.manager.request_blocking(method_str, params, error_formatters)
#      58         return apply_result_formatters(result_formatters, result)
#      59     return caller
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\manager.py in request_blocking(self, method, params, error_formatters)
#     152         Make a synchronous request using the provider
#     153         """
# --> 154         response = self._make_request(method, params)
#     155
#     156         if "error" in response:
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\manager.py in _make_request(self, method, params)
#     131             self.middleware_onion)
#     132         self.logger.debug("Making request. Method: %s", method)
# --> 133         return request_func(method, params)
#     134
#     135     async def _coro_make_request(
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\formatting.py in apply_formatters(method, params, make_request, request_formatters, result_formatters, error_formatters)
#      74         response = make_request(method, formatted_params)
#      75     else:
# ---> 76         response = make_request(method, params)
#      77
#      78     if "result" in response and method in result_formatters:
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\gas_price_strategy.py in middleware(method, params)
#      32                     transaction = assoc(transaction, 'gasPrice', generated_gas_price)
#      33                     return make_request(method, [transaction])
# ---> 34         return make_request(method, params)
#      35     return middleware
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\formatting.py in apply_formatters(method, params, make_request, request_formatters, result_formatters, error_formatters)
#      72         formatter = request_formatters[method]
#      73         formatted_params = formatter(params)
# ---> 74         response = make_request(method, formatted_params)
#      75     else:
#      76         response = make_request(method, params)
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\attrdict.py in middleware(method, params)
#      31     """
#      32     def middleware(method: RPCEndpoint, params: Any) -> RPCResponse:
# ---> 33         response = make_request(method, params)
#      34
#      35         if 'result' in response:
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\formatting.py in apply_formatters(method, params, make_request, request_formatters, result_formatters, error_formatters)
#      72         formatter = request_formatters[method]
#      73         formatted_params = formatter(params)
# ---> 74         response = make_request(method, formatted_params)
#      75     else:
#      76         response = make_request(method, params)
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\normalize_errors.py in middleware(method, params)
#      23 ) -> Callable[[RPCEndpoint, Any], RPCResponse]:
#      24     def middleware(method: RPCEndpoint, params: Any) -> RPCResponse:
# ---> 25         result = make_request(method, params)
#      26
#      27         # As of v1.8, Geth returns errors when you request a
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\formatting.py in apply_formatters(method, params, make_request, request_formatters, result_formatters, error_formatters)
#      72         formatter = request_formatters[method]
#      73         formatted_params = formatter(params)
# ---> 74         response = make_request(method, formatted_params)
#      75     else:
#      76         response = make_request(method, params)
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\formatting.py in apply_formatters(method, params, make_request, request_formatters, result_formatters, error_formatters)
#      72         formatter = request_formatters[method]
#      73         formatted_params = formatter(params)
# ---> 74         response = make_request(method, formatted_params)
#      75     else:
#      76         response = make_request(method, params)
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\providers\eth_tester\middleware.py in middleware(method, params)
#     337                 fill_default_from,
#     338             )
# --> 339             return make_request(method, [filled_transaction] + list(params)[1:])
#     340         else:
#     341             return make_request(method, params)
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\middleware\formatting.py in apply_formatters(method, params, make_request, request_formatters, result_formatters, error_formatters)
#      72         formatter = request_formatters[method]
#      73         formatted_params = formatter(params)
# ---> 74         response = make_request(method, formatted_params)
#      75     else:
#      76         response = make_request(method, params)
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\providers\eth_tester\main.py in make_request(self, method, params)
#     100             )
#     101         try:
# --> 102             response = delegator(self.ethereum_tester, params)
#     103         except NotImplementedError:
#     104             return RPCResponse(
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\cytoolz\functoolz.pyx in cytoolz.functoolz.curry.__call__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\web3\providers\eth_tester\defaults.py in call_eth_tester(fn_name, eth_tester, fn_args, fn_kwargs)
#      64     if fn_kwargs is None:
#      65         fn_kwargs = {}
# ---> 66     return getattr(eth_tester, fn_name)(*fn_args, **fn_kwargs)
#      67
#      68
#
# C:\ProgramData\Anaconda3\lib\site-packages\eth_tester\main.py in estimate_gas(self, transaction, block_number)
#     434         self.validator.validate_inbound_block_number(block_number)
#     435         raw_block_number = self.normalizer.normalize_inbound_block_number(block_number)
# --> 436         raw_gas_estimate = self.backend.estimate_gas(raw_transaction, raw_block_number)
#     437         self.validator.validate_outbound_gas_estimate(raw_gas_estimate)
#     438         gas_estimate = self.normalizer.normalize_outbound_gas_estimate(raw_gas_estimate)
#
# TypeError: estimate_gas() takes 2 positional arguments but 3 were given
